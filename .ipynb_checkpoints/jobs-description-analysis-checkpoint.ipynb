# %%
# %%time
import csv
import os #用於讀取文件列表
import pandas as pd
from string import punctuation
pd.set_option('max_rows',6000)
pd.set_option('max_colwidth',100)
punctuation += '\"“”‘’—-–'


def count_frequency(text):
    def kill_punctuations_capitals(text): 
        text = text.replace("’s","") #需要先去除‘s，否則去除標點會留下如chinas，truups這樣的詞
        translator = str.maketrans("","",punctuation) 
        #等價於translator = str.maketrans(punctuation,len(punctuation)*' ')
        #note:str.maketrans(input,output,delete)，input,output長度必須相等
        list_lowercase_without_punctuation = text.lower().translate(translator).split()
        #將大寫字母轉化為小寫，去除標點，列出單詞
        return list_lowercase_without_punctuation


    def extract_meaningful(list): #去除無意義的單詞
        list_meaningful_words = []
        with open ('stopword.txt','r') as s:
            list_stop_words = s.read().split() #讀取stoplist
        for m in list:
            if m not in list_stop_words:
                list_meaningful_words.append(m)
        return list_meaningful_words

    def words_frequency(list): #統計一篇文章中的frequency
        dict_words_frequency={}
        for m in list:
            dict_words_frequency[m]=list.count(m)
        return dict_words_frequency
    return words_frequency(extract_meaningful(kill_punctuations_capitals(text)))


def update_dict(dict0,dict1): #兩個txt中的frequency相加
    for k,v in dict1.items():
        if dict0.__contains__(k):
            dict0[k] += v
        else:
            dict0.update({k : dict1[k]})

def rank_frequency(dict): #根據frequency排序，也可以最後用print(s.sort_values(ascending=False))，但是不方便寫cvs
    dict_frequency_rank={}
    rank = sorted(dict.items(), key=lambda item: item[1], reverse=True) 
    #將字典轉化爲二元數組，並根據字典中value排序
    for m in range(0,len(rank)):
        dict_frequency_rank.update({rank[m][0]:rank[m][1]})
    #再將字典重新整合起來
    return dict_frequency_rank

def write_csv(dict):
    with open('description-keywords-frequency.csv','w',newline='') as f:
        writer = csv.writer(f,delimiter=',')
        header = ['keyword','frequency']
        writer.writerow(header)
        writer.writerows(dict.items())


dict_accumulate_frequency = {} #所有文件中的frequency
dict_text_frequency = {} #單個文件中的frequency，方便日後分析每個文件
with open("jobs.csv",'r') as f:
    csv_reader = csv.reader(f)
    for i in csv_reader:
        frequency = count_frequency(i[8])
        dict_text_frequency[i[1]] = rank_frequency(frequency)
        update_dict(dict_accumulate_frequency,frequency) #累計到dict_accumulate_frequency
dict_frequency_rank = rank_frequency(dict_accumulate_frequency) #排序
write_csv(dict_frequency_rank)
# Out:
# CPU times: user 946 ms, sys: 23.1 ms, total: 969 ms
# Wall time: 980 ms

# %%
df = pd.read_csv('description-keywords-frequency.csv').head(500)
df.to_csv('description-keywords-frequency-rank500.csv')
df
# Out:
#               keyword  frequency
# 0               media        666
# 1                work        565
# 2          experience        536
# 3             program        457
# 4                data        385
# 5            research        385
# 6              social        358
# 7              skills        335
# 8             ability        321
# 9                team        314
# 10               news        309
# 11            content        295
# 12         university        291
# 13          including        285
# 14           position        284
# 15          marketing        282
# 16        development        263
# 17        information        262
# 18            support        231
# 19           programs        223
# 20                new        218
# 21     communications        216
# 22            digital        209
# 23            working        200
# 24                job        185
# 25              apply        173
# 26             strong        172
# 27         management        170
# 28            include        170
# 29              staff        161
# 30       professional        158
# 31           software        156
# 32        opportunity        154
# 33             degree        153
# 34          education        153
# 35            develop        148
# 36             public        148
# 37      communication        147
# 38          knowledge        145
# 39            related        142
# 40           projects        139
# 41         journalism        138
# 42            through        135
# 43           students        134
# 44         candidates        134
# 45            provide        133
# 46        application        133
# 47         department        131
# 48           business        131
# 49          community        131
# 50         applicants        129
# 51             design        128
# 52       applications        128
# 53                web        127
# 54             online        127
# 55             health        127
# 56            writing        127
# 57              world        126
# 58           required        125
# 59             please        125
# 60             school        125
# 61           internal        124
# 62           learning        122
# 63            science        122
# 64        association        121
# 65              years        119
# 66             status        118
# 67           employer        114
# 68         employment        114
# 69          extension        114
# 70           national        113
# 71        programming        112
# 72            college        112
# 73            stories        111
# 74          excellent        110
# 75             duties        110
# 76             assist        110
# 77          diversity        109
# 78             events        109
# 79           director        109
# 80        environment        108
# 81         technology        107
# 82         activities        105
# 83         production        104
# 84           computer        103
# 85            systems        102
# 86              tools        102
# 87          platforms        101
# 88        individuals        100
# 89             number        100
# 90            diverse        100
# 91            faculty         99
# 92          materials         99
# 93             career         98
# 94   responsibilities         97
# 95          relations         97
# 96              areas         96
# 97               time         95
# 98            website         95
# 99              using         94
# 100              help         94
# 101             local         94
# 102         resources         93
# 103            manage         93
# 104         candidate         93
# 105     opportunities         93
# 106          creative         92
# 107         reporting         92
# 108            report         91
# 109             equal         91
# 110          teaching         91
# 111        internship         91
# 112            office         90
# 113           student         90
# 114           company         89
# 115              meet         89
# 116           service         88
# 117    qualifications         88
# 118      requirements         88
# 119             based         87
# 120              role         86
# 121           efforts         86
# 122              best         85
# 123           current         85
# 124             video         85
# 125          analysis         84
# 126          relevant         84
# 127          maintain         84
# 128        background         83
# 129            gender         83
# 130            across         83
# 131             state         83
# 132             youth         83
# 133           written         82
# 134          graduate         81
# 135       journalists         81
# 136       cooperative         81
# 137          academic         80
# 138         editorial         80
# 139             ideas         80
# 140       coordinator         80
# 141             build         79
# 142      organization         79
# 143             field         78
# 144               law         78
# 145            letter         78
# 146       educational         78
# 147             cover         77
# 148           cornell         77
# 149        disability         75
# 150          existing         75
# 151           project         74
# 152        developing         74
# 153     understanding         74
# 154          multiple         74
# 155            should         74
# 156            create         74
# 157              plan         73
# 158             needs         73
# 159          services         73
# 160            cancer         71
# 161           limited         71
# 162           members         71
# 163         strategic         71
# 164            policy         71
# 165              make         70
# 166               age         70
# 167           looking         70
# 168       engineering         70
# 169        excellence         69
# 170          building         69
# 171       established         69
# 172          assigned         68
# 173             press         68
# 174          industry         67
# 175          benefits         67
# 176          audience         66
# 177            resume         66
# 178            center         66
# 179        evaluation         66
# 180              join         65
# 181       responsible         65
# 182          managing         65
# 183         committed         65
# 184            impact         65
# 185            family         65
# 186              high         64
# 187             color         64
# 188       orientation         64
# 189           variety         64
# 190         analytics         64
# 191           reports         64
# 192            campus         64
# 193               use         63
# 194             under         63
# 195           veteran         63
# 196        successful         63
# 197     undergraduate         63
# 198           various         63
# 199        engagement         63
# 200         employees         62
# 201         qualified         62
# 202        innovative         62
# 203            people         62
# 204               top         61
# 205            ensure         61
# 206            origin         61
# 207         providing         61
# 208           closely         61
# 209           editing         61
# 210            county         61
# 211              only         60
# 212          religion         60
# 213         assistant         60
# 214             learn         60
# 215             email         60
# 216            member         60
# 217           contact         60
# 218         protected         60
# 219            global         60
# 220            action         59
# 221          planning         59
# 222              race         59
# 223               key         59
# 224              into         59
# 225      demonstrated         59
# 226            alumni         59
# 227              part         58
# 228           federal         58
# 229        leadership         58
# 230           general         58
# 231          educator         58
# 232               msk         57
# 233          identity         57
# 234            sexual         57
# 235          expected         57
# 236             brand         57
# 237      participants         57
# 238          interest         56
# 239             hours         56
# 240              used         55
# 241           medical         55
# 242        multimedia         55
# 243            intern         55
# 244             goals         54
# 245           complex         54
# 246        reasonable         54
# 247           process         54
# 248       initiatives         54
# 249         technical         54
# 250          regional         54
# 251            needed         54
# 252           interns         54
# 253           mission         53
# 254       communicate         53
# 255           success         53
# 256         effective         53
# 257          includes         53
# 258     relationships         53
# 259              most         53
# 260               day         52
# 261          creating         52
# 262           minimum         52
# 263            senior         52
# 264          personal         52
# 265        strategies         52
# 266      technologies         51
# 267          strategy         51
# 268            offers         51
# 269         implement         50
# 270       effectively         50
# 271       recruitment         50
# 272         standards         50
# 273           special         50
# 274        innovation         49
# 275     collaboration         49
# 276          clinical         49
# 277          training         49
# 278            highly         49
# 279             basis         49
# 280              plus         49
# 281             serve         49
# 282            issues         49
# 283         positions         49
# 284        coordinate         49
# 285             print         49
# 286            leader         49
# 287     accommodation         48
# 288      disabilities         48
# 289            review         48
# 290       afterschool         48
# 291       performance         47
# 292            timely         47
# 293     consideration         47
# 294            editor         47
# 295        considered         47
# 296          provides         47
# 297        individual         47
# 298             sales         47
# 299        additional         46
# 300              2019         46
# 301         campaigns         46
# 302            system         46
# 303             story         46
# 304          flexible         46
# 305    administrative         46
# 306            market         46
# 307          external         46
# 308               way         45
# 309              year         45
# 310        healthcare         45
# 311            regard         45
# 312              full         45
# 313             range         45
# 314             event         45
# 315         audiences         44
# 316         bachelors         44
# 317           perform         44
# 318            visual         44
# 319           machine         44
# 320           promote         44
# 321       advertising         44
# 322          internet         44
# 323           manager         44
# 324           seeking         43
# 325          products         43
# 326              site         43
# 327              care         43
# 328            salary         43
# 329            sports         43
# 330              paid         43
# 331            record         42
# 332            growth         42
# 333       appropriate         42
# 334     independently         42
# 335         associate         42
# 336              area         42
# 337              show         42
# 338         deadlines         42
# 339          specific         42
# 340              list         41
# 341              take         41
# 342         professor         41
# 343     organizations         41
# 344       collaborate         41
# 345     comprehensive         41
# 346            submit         41
# 347             plans         41
# 348           leading         40
# 349           conduct         40
# 350            around         40
# 351          fulltime         40
# 352     international         40
# 353         following         40
# 354           methods         40
# 355        recognized         40
# 356       departments         40
# 357         essential         40
# 358          strongly         40
# 359         executive         40
# 360          changing         39
# 361          database         39
# 362              life         39
# 363        contribute         39
# 364           receive         39
# 365          graphics         39
# 366          coverage         39
# 367          channels         39
# 368             tasks         39
# 369         direction         39
# 370            annual         39
# 371         nutrition         39
# 372               art         39
# 373             great         38
# 374            making         38
# 375              lead         38
# 376           aspects         38
# 377            trends         38
# 378             excel         38
# 379             daily         38
# 380             teams         38
# 381     institutional         38
# 382             group         37
# 383        equivalent         37
# 384        encouraged         37
# 385       demonstrate         37
# 386             visit         37
# 387             women         37
# 388          problems         37
# 389           sources         37
# 390          engaging         37
# 391         practices         37
# 392           culture         37
# 393           produce         37
# 394          customer         37
# 395              here         36
# 396          delivery         36
# 397            during         36
# 398             offer         36
# 399              live         35
# 400             level         35
# 401               phd         35
# 402         expertise         35
# 403           located         35
# 404             check         35
# 405           subject         35
# 406              edit         35
# 407        interested         35
# 408          together         34
# 409          requires         34
# 410    bioinformatics         34
# 411    organizational         34
# 412            engage         34
# 413        curriculum         34
# 414            groups         34
# 415      publications         34
# 416       competitive         34
# 417         attention         34
# 418             focus         34
# 419          security         34
# 420           prepare         34
# 421               sex         34
# 422             works         34
# 423           twitter         34
# 424           network         34
# 425           leaders         34
# 426              food         34
# 427       advancement         34
# 428         athletics         34
# 429       proficiency         33
# 430        expression         33
# 431          division         33
# 432      storytelling         33
# 433         questions         33
# 434        commitment         33
# 435            detail         33
# 436            access         33
# 437          agencies         33
# 438           english         33
# 439         corporate         33
# 440            safety         33
# 441             place         32
# 442           dynamic         32
# 443     computational         32
# 444         solutions         32
# 445        priorities         32
# 446       institution         32
# 447                pr         32
# 448              week         32
# 449             ideal         32
# 450        washington         32
# 451          michigan         32
# 452             write         32
# 453            direct         32
# 454              send         32
# 455         available         32
# 456             share         32
# 457           desired         32
# 458           utilize         32
# 459          complete         31
# 460      partnerships         31
# 461         potential         31
# 462       familiarity         31
# 463       affirmative         31
# 464         inclusion         31
# 465        recruiting         31
# 466              tell         31
# 467           require         31
# 468        procedures         31
# 469          veterans         31
# 470         financial         31
# 471        operations         31
# 472          partners         31
# 473              open         31
# 474           improve         31
# 475           account         31
# 476           growing         31
# 477            travel         31
# 478             issue         31
# 479           results         30
# 480             track         30
# 481           deliver         30
# 482         databases         30
# 483             bring         30
# 484        applicable         30
# 485               seo         30
# 486           package         30
# 487           quality         30
# 488            google         30
# 489            states         30
# 490            region         30
# 491           clients         30
# 492              user         30
# 493        volunteers         30
# 494          outcomes         29
# 495          identify         29
# 496          organize         29
# 497             least         29
# 498            change         29
# 499            proven         29
