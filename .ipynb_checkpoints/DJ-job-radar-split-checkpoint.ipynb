# %%
import requests
from bs4 import BeautifulSoup
def scrape_careers_information(page_url):
    r = requests.get(page_url)
    data = BeautifulSoup(r.text,"html.parser")
    jobs= []
    all_div = data.find_all('div', attrs={'class':"bti-ui-job-detail-container"}) 
    for i in all_div:
        job=[]
        job.append(i.find('a').text)
        job.append(i.find('div', attrs={'class':"bti-ui-job-result-detail-employer"}).text.strip())
        job.append(i.find('div', attrs={'class':"bti-ui-job-result-detail-location"}).text.strip())
        job.append(i.find('div', attrs={'class':"bti-ui-job-result-detail-age"}).text.strip())
        job.append('https://careers.journalists.org{}'.format(i.find('a')['href']))
        job.append('careers')
        jobs.append(job)
    return jobs

def scrape_careers_description(description_url):
    r = requests.get(description_url)
    data = BeautifulSoup(r.text,"html.parser")
    return data.find('div', attrs={'class':"bti-jd-description"}).text

def scrape_indeed_information(page_url):
    r = requests.get(page_url)
    data = BeautifulSoup(r.text,"html.parser")
    jobs= []
    all_h2 = data.find_all('h2', attrs={'class':"jobtitle"}) 
    #it's a weirdo page that the last item's 'class' is different from above 9, so that we use its sub label h2.
    for i in all_h2:
        job = []
        job.append(i.a['title'])
        job.append(i.parent.find('span', attrs={'class':"company"}).text.strip()) 
        #use .parent back to the higher label
        job.append(i.parent.find('span', attrs={'class':"location"}).text.strip())
        job.append(i.parent.find('span', attrs={'class':"date"}).text.strip())
        job.append('https://www.indeed.com/viewjob?jk={}'.format(i['id'][3:]))
        job.append('indeed')
        if job not in all_jobs:
            jobs.append(job)
        #when the index url exceeds the range of pages in indeed, the page will become circulation, so that we should do duplicate checking
    return jobs

def scrape_indeed_description(description_url):
    r = requests.get(description_url)
    data = BeautifulSoup(r.text,"html.parser")
    return data.find('div', attrs={'class':"jobsearch-JobComponent-description icl-u-xs-mt--md"}).text

def scrape_jobsdb_information(page_url):
    r = requests.get(page_url)
    data = BeautifulSoup(r.text,"html.parser")
    jobs= []
    all_div = data.find_all('div', attrs={'class':"_3ASfTyv _2EUSthc"})
    for i in all_div:
        job=[]
        job.append(i.find('div', attrs={'class':"_3gfm7U9 _3ho-Knb _2swcdgn"}).a.text)
        job.append(i.find('div', attrs={'class':"_1NdWRqw _3ho-Knb _2swcdgn"}).find('span').text)
        job.append(i.find('div', attrs={'class':"_124cxoK _3ho-Knb _2swcdgn"}).find('span').text)
        job.append(i.find('span', attrs={'class':"JG37Vx2 _3Re95QG _2XGgj_O"}).find('span').text)
        job.append(i.find('div', attrs={'class':"_3gfm7U9 _3ho-Knb _2swcdgn"}).a['href'])
        job.append('jobsdb')
        jobs.append(job)
    return jobs
    
def scrape_jobsdb_description(description_url):
    r = requests.get(description_url)
    data = BeautifulSoup(r.text,"html.parser")
    return data.find('div', attrs={'class':"jobad-primary"}).text

def scrape_all_information(base_url,starting_index,step,function_scrape_information):
    global all_jobs
    all_jobs = [] 
    page_index = starting_index
    while True: 
        page_url = '{}{}'.format(base_url,page_index)
        try:
            jobs = function_scrape_information(page_url)
        except:
            jobs = []   
        if jobs == []: #if all jobs have been scraped, break the loop
            break
        all_jobs.extend(jobs)
        if len(all_jobs) > 5: #only scrape 50 jobs from each website
            break
        page_index += step  #level is in url to indiccate different pages' index
#     all_jobs.sort(key=lambda item: item[3], reverse=False) 

def scrape_all_description(urls_and_sources):
    list_descriptions = []
    list_websites = [m["source"] for m in websites]
    list_functions = [i["function_scrape_description"] for i in websites]
    for u, s in urls_and_sources:
        list_descriptions.append(list_functions[list_websites.index(s)](u))
    return list_descriptions

websites = [
    {
        "source": 'careers',
        "base_url": 'https://careers.journalists.org/jobs/?keywords=data+OR+journalist&page=',
        "starting_index": 1,        
        "step": 1,
        "function_scrape_information": scrape_careers_information,
        "function_scrape_description": scrape_careers_description,
    }, 
    {
        "source": 'indeed',
        "base_url": 'https://www.indeed.com/jobs?q=Data+Journalist+Internship&start=',
        "starting_index": 0,        
        "step": 10,
        "function_scrape_information": scrape_indeed_information,
        "function_scrape_description": scrape_indeed_description,
    },
    {
        "source": 'jobsdb',
        "base_url": 'https://hk.jobsdb.com/hk/search-jobs/data-journalist/',
        "starting_index": 1,        
        "step": 1,
        "function_scrape_information": scrape_jobsdb_information,
        "function_scrape_description": scrape_jobsdb_description,
    },
]

# %%
import csv
from os import remove
try:
    e = open('existedjobs.csv','r')
    jobs_existed_url = [row[4] for row in csv.reader(e)]
    e.close()
except FileNotFoundError:
    jobs_existed_url = []
try:
    remove('newjobs.csv')
except FileNotFoundError:
    pass
for i in websites:
    scrape_all_information(i["base_url"],i["starting_index"],i["step"],i["function_scrape_information"])
    e = open('existedjobs.csv','a')
    n = open('newjobs.csv','a')
    for a in all_jobs:
        if a[4] not in jobs_existed_url: #duplicate checking
            csv.writer(e).writerow(a)
            csv.writer(n).writerow(a)
    e.close()
    n.close()

# %%
# %%time
import pandas as pd
df=pd.read_csv('existedjobs.csv', header=None, names=['Title','Company','Location','Date','URL','Source'])
urls_and_sources = zip(df['URL'].tolist(), df['Source'].tolist())
df['Description'] = scrape_all_description(urls_and_sources)
# Out:
# CPU times: user 2.42 s, sys: 72.3 ms, total: 2.49 s
# Wall time: 52.9 s

# %%
df
# Out:
#                                                 Title  \
# 0                                        Data Analyst
# 1               Assistant Professor - Data Journalism
# 2               Assistant Professor - Data Journalism
# 3                                  Sr. Data Scientist
# 4                 Digital Communications Data Analyst
# 5               Ops Research Engineer/ Data Scientist
# 6   Assistant Professor in Computer and Informatio...
# 7   Assistant Professor in Computer and Informatio...
# 8                       Senior Investigative Reporter
# 9                           Deputy online news editor
# 10           Ogden Newspapers Professor of Journalism
# 11            Associate Producer, MPR News Talk Shows
# 12         Europe and Central Asia Research Associate
# 13  Weekend Anchor/ General Assignment Reporter, K...
# 14  Assistant or Associate Professor of Journalism...
# 15                    Orange County Reporter, KABC-TV
# 16  Senior Editor and Digital Content Strategist, ...
# 17                WAMU Spring 2019 Internship Program
# 18        Professional in Residence (Content Adviser)
# 19                     Science & Environment Producer
# 20               Associate Producer, MPR News #152-19
# 21                 Strategic Partnerships Coordinator
# 22  Director of Media Relations, Berkeley Law - (7...
# 23                                   Podcast Producer
# 24                            Digital Content Creator
# 25                             Data Journalist Intern
# 26                                  Data Entry Intern
# 27              Product Management Intern Summer 2019
# 28                  Editorial Intern- Everyday Health
# 29                                      Sports Intern
# 32  https://www.indeed.com/viewjob?jk=58bbc332cbf4...   indeed
# 33  https://www.indeed.com/viewjob?jk=64bd730d3ceb...   indeed
# 34  https://www.indeed.com/viewjob?jk=562f3ae8b5f4...   indeed
# 35  https://hk.jobsdb.com/hk/en/job/journalist-fin...   jobsdb
# 36  https://hk.jobsdb.com/hk/en/job/sales-marketin...   jobsdb
# 37  https://hk.jobsdb.com/hk/en/job/marketing-exec...   jobsdb
# 38  https://hk.jobsdb.com/hk/en/job/healthcare-ind...   jobsdb
# 39  https://hk.jobsdb.com/hk/en/job/account-direct...   jobsdb
# 40  https://hk.jobsdb.com/hk/en/job/sr-public-rela...   jobsdb
# 41  https://hk.jobsdb.com/hk/en/job/android-develo...   jobsdb
# 42  https://hk.jobsdb.com/hk/en/job/manager-extern...   jobsdb
# 43  https://hk.jobsdb.com/hk/en/job/lead-manager-m...   jobsdb
# 44  https://hk.jobsdb.com/hk/en/job/content-expert...   jobsdb
# 45  https://hk.jobsdb.com/hk/en/job/womens-wear-br...   jobsdb
# 46  https://hk.jobsdb.com/hk/en/job/media-relation...   jobsdb
# 47  https://hk.jobsdb.com/hk/en/job/womens-wear-br...   jobsdb
#
#                                           Description
# 0   \n Company Overview:   At Memorial Sloan Kette...
# 1   \n Job Description:Syracuse University's S.I. ...
# 2   \n Assistant Professor - Data JournalismThe S....
# 3   \n Company Overview:   At Memorial Sloan Kette...
# 4   \n Who We Are: NAM Strategic Communications is...
# 5   \n Company Overview:   At Memorial Sloan Kette...
# 6   \n A cover letter, curriculum vitae, teaching ...
# 7   \n A cover letter, curriculum vitae, teaching ...
# 8   \n Welcome. We are The Markup (https://themark...
# 9   \n Arkansas' premier statewide newspaper, the ...
# 10  \n The West Virginia University Reed College o...
# 11  \n Position Summary:  \r\nIf you stay on top o...
# 12  \n Position:       Europe and Central Asia Res...
# 13  \n ABC7 Los Angeles seeks a Weekend Anchor/ Ge...
# 14  \n The Drake School of Journalism and Mass Com...
# 15  \n KABC-TV, the ABC Owned local TV and digital...
# 16  \n Since 1999, Harvard Business School Working...
# 17  \n  WAMU Spring 2019 Internship Program   Work...
# 18  \n Professional in Residence (Content Adviser)...
# 19  \n Cascade Public Media is looking for an expe...
# 20  \n About Us:  \r\nMPR News has long been recog...
# 21  \n The Online News Association (ONA) is seekin...
# 22  \n Job Requisition Number: 24843. Berkeley Law...
# 23  \n Location: Hyde Park CampusJob Description:J...
# 24  \n Reporting to the Director of Editorial Stra...
# 25  InternshipDesired: AP StyleJournalismHTML5Date...
# 26  $14 an hourInternshipThe Scholars Strategy Net...
# 27  Temporary, InternshipDesired: Leadership Exper...
# 28  InternshipEverydayHealth.com, the leading heal...
# 29  InternshipDate: Oct 25, 2018\nLocation: NY, US...
# 30  Join the 2019 New York Times Fellowship class ...
# 31  $15 an hourPart-time, InternshipWAMU Spring 20...
# 32  Part-time, InternshipDesired: Time ManagementM...
# 33  Desired: Microsoft WordMicrosoft PowerpointExc...
# 34  Part-time, InternshipSummary\n\nThe Intern, Me...
# 35             Initiative Recruitment Hong Kong Li...
# 36           Cochine Limited        Sales & Market...
# 37             Hong Kong Trade Development Council...
# 38           Standard & Poor's International, LLC ...
# 39                 Account Director / Associate Ac...
# 40             Global Sources    \n\nGlobal Source...
# 41           Dow Jones & Co    When you join Dow J...
# 42             Urban Renewal Authority    The Urba...
# 43             Hong Kong Productivity Council    T...
# 44        Telum Media HK Limited    Telum Media is...
# 45           Emma Wallace    Emma Wallace born and...
# 46             Hong Kong Trade Development Council...
# 47           Emma Wallace    Emma Wallace born and...

# %%
import pandas
df = pandas.read_csv('newjobs.csv', header=None, names=['Title','Company','Location','Date','URL','Source','Description'])
df
# Out:
#                                                 Title  \
# 0                   Journalist – Financial Publishing
# 1   Sales & Marketing Assistant, Luxury Goods Company
# 2   Marketing Executive, Exhibitions (Marketing Co...
# 3                          Healthcare Industry Editor
# 4   Account Director / Associate Account Director ...
# 5                      Sr. Public Relations Executive
# 6                                   Android Developer
# 7            Manager, External Relations (Ref. M(ER))
# 8   Lead Manager, Media Relations (Corporate Devel...
# 9                                      Content Expert
# 10         Women’s Wear Brand - Marketing Coordinator
# 11                          Media Relations Executive
# 12         Women’s Wear Brand - Marketing Coordinator
# 13         Women’s Wear Brand - Marketing Coordinator
#
#                                      Company                Location  \
# 0   Initiative Recruitment Hong Kong Limited           Not Specified
# 1                            Cochine Limited  Central & Western Area
# 2        Hong Kong Trade Development Council           Wan Chai Area
# 3       Standard & Poor's International, LLC      Yau Tsim Mong Area
# 4             Bentley Communications Limited       Sham Shui Po Area
# 5                             Global Sources           Southern Area
# 6                             Dow Jones & Co           Wan Chai Area
# 7                    Urban Renewal Authority           Not Specified
# 8             Hong Kong Productivity Council           Not Specified
# 9                     Telum Media HK Limited            Eastern Area
# 10                              Emma Wallace  Central & Western Area
# 11       Hong Kong Trade Development Council           Wan Chai Area
# 12                              Emma Wallace  Central & Western Area
# 13                              Emma Wallace  Central & Western Area
#
#          Date                                                URL  source  \
# 0   09-Nov-18  https://hk.jobsdb.com/hk/en/job/journalist-fin...     NaN
# 1   07-Nov-18  https://hk.jobsdb.com/hk/en/job/sales-marketin...     NaN
# 2   05-Nov-18  https://hk.jobsdb.com/hk/en/job/marketing-exec...     NaN
# 3   02-Nov-18  https://hk.jobsdb.com/hk/en/job/healthcare-ind...     NaN
# 4   02-Nov-18  https://hk.jobsdb.com/hk/en/job/account-direct...     NaN
# 5   30-Oct-18  https://hk.jobsdb.com/hk/en/job/sr-public-rela...     NaN
# 6   26-Oct-18  https://hk.jobsdb.com/hk/en/job/android-develo...     NaN
# 7   22-Oct-18  https://hk.jobsdb.com/hk/en/job/manager-extern...     NaN
# 8   22-Oct-18  https://hk.jobsdb.com/hk/en/job/lead-manager-m...     NaN
# 9   19-Oct-18  https://hk.jobsdb.com/hk/en/job/content-expert...     NaN
# 10  19-Oct-18  https://hk.jobsdb.com/hk/en/job/womens-wear-br...     NaN
# 11  18-Oct-18  https://hk.jobsdb.com/hk/en/job/media-relation...     NaN
# 12  18-Oct-18  https://hk.jobsdb.com/hk/en/job/womens-wear-br...     NaN
# 13  12-Oct-18  https://hk.jobsdb.com/hk/en/job/womens-wear-br...     NaN
#
#     discription
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
